# %% [markdown]
# # 07 — Visualization v2
#
# Superseded by `06_visualization.ipynb` + `src/fqw/viz/`.
#
# Legacy notebook archived at `archive/07_visualization_v2_legacy.ipynb`.

# %%
print("Use notebooks/06_visualization.ipynb")
