# %% [markdown]
# # 08 — Optimal Alpha Search
#
# Find per-ticker alpha targeting ~60% flat labels.
#
# Core logic: `src/fqw/labeling/alpha_search.py`

# %%
# !pip install -e ".."

from fqw.labeling import run_alpha_search, summarize_alpha_search

res_df = run_alpha_search(data_dir="../data", window_size=24, target_flat_pct=0.60)
res_df.head()

# %%
summarize_alpha_search(res_df)
